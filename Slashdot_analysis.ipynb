# %% [markdown]
# <a href="https://colab.research.google.com/github/manasi517/web-scrapper-slashdot/blob/main/Slashdot_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql

# %%
import sqlalchemy as sql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
engine = sql.create_engine('mysql://root:Manc123@4.tcp.ngrok.io:15368/mysql')

# %%
q="select * from comment"

# %%
df=pd.read_sql_query(q, engine)

# %%
df.head()
# Out:
#    id      cls  comment_code  ...        type  article_id parent_comment_id
# 0   1  ONELINE      61470098  ...        None           1               2.0
# 1   2  ONELINE      61468834  ...        None           1               6.0
# 2   3  ONELINE      61468838  ...  Insightful           1               6.0
# 3   4  ONELINE      61469128  ...        None           1               6.0
# 4   5  ONELINE      61470492  ...        None           1               6.0
#
# [5 rows x 14 columns]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
df.plot(kind="hist", y="depth", bins=70, color="b", ax=axes[0][0])
df.plot(kind="hist", y="reply_count", bins=100, color="r", ax=axes[0][1])
df.plot(kind="hist", y="score", bins=6, color="g", ax=axes[1][0])
plt.show()

# %%
df.corr()
# Out:
#                          id  comment_code  ...  article_id  parent_comment_id
# id                 1.000000      0.912004  ...    0.926773           0.998809
# comment_code       0.912004      1.000000  ...    0.953086           0.919950
# depth             -0.115080     -0.081194  ...   -0.086120          -0.057744
# reply_count       -0.106622     -0.080107  ...   -0.076196          -0.027446
# score              0.011781      0.001782  ...    0.000941           0.071132
# article_id         0.926773      0.953086  ...    1.000000           0.938373
# parent_comment_id  0.998809      0.919950  ...    0.938373           1.000000
#
# [7 rows x 7 columns]

# %%
sns.set(style="ticks")
pal = ["#FA5858", "#58D3F7"]

sns.pairplot(df, hue="type")
plt.title("Smokers")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Smokers')
